# %% [markdown]
# # COGS 108 Final Project Check-In

# %% [markdown]
# # Names
#
# 1. Zanyuan Yang
# 2. Zihao Chen
# 3. Alex Guo
# 4. Yiyang Yin
# 5. Sijie Wang

# %% [markdown]
# # Group Members IDs
#
# 1. A16079340
# 2. A16085539
# 3. A13907234
# 4. A92112108
# 5. A16061925

# %% [markdown]
# # Accomplishments

# %% [markdown]
# We have collected and cleaned the two parts of data we need, some of them are visualized in below to give a sense of our data.

# %%
df_confirm_first_14days.plot(
    kind='bar',
    x='Province/State',
    y='after_14days_lockdown',
    figsize=(20,10),
    title='total case of each country(14day)'
);plt.show()

# %%
df_confirm_second_14days.plot(
    kind='bar',
    x='Province/State',
    y='another_14days_lockdown',
    figsize=(20,10),
    title='total case of each country(another 14 day)'
);plt.show()

# %% [markdown]
# For number of people going in and out Wuhan, Hubei, We summarized and cleaned those data in the form of xlsx files in the attached folder "baidu qianxi". Please refer to the data in that folder to check our progress on datasets.
# It has been quite some time for us to prepare the best datasets, but it is worth it. We can now march into data analysis with clean and supportive data as we need.

# %% [markdown]
# # Going Well

# %% [markdown]
# For data collection and wrangling: From GitHub and Baidu Qianxi, we have collected relatively complete data on the diagnosis of the new coronavirus cases in Wuhan and the moving population in and out of Wuhan and Hubei, the province where Wuhan is located.
# For visualization: We plotted the daily increase in the number of confirmed cases to get a better picture of the rate and number of new coronavirus cases in Wuhan.
# For defining model and future predictive analysis:
# We have identified two objects to be studied in this project, and we are going to find the correlation between the rate of infection of Wuhan coronavirus cases and the population flow of Wuhan.

# %% [markdown]
# # Struggles

# %% [markdown]
# First of all, to get the best analysis result, we wish to have the most specific data about the exact number of people going in and out the city of Wuhan, but we were not able to find data tailored to our need. Right now we have the percentage of people going in and out of Wuhan, collected based on cellphone map data. We may have to use this data together with an estimation of total number of people in and out Wuhan during the past month.
# Second of all, the model we hope to build now seems to be quite a complicated one, with more parameters than we thought. We are now trying to find the preliminary relation between our datasets to get a feeling about it, but it may take more time than we expected to finish the statistical analysis.

# %% [markdown]
# # Plan Forward

# %% [markdown]
# Our detailed plan for completing this project is listed below for each week to come.
# Week 7: Complete data collection, summarize the data and submit project check-in.
# Week 8: Start data analysis including reporting the summarizes with interpretation, exploring the data.
# Week 9: Predict based on the analysis of data, set up appropriate models and attempt to inference for the association between variables. Most analysis will be completed at this time.
# Week 10: Edit the project, make small improvements.
# Final week: submit the final Jupyter notebook on Github and prepare for the presentation.
# Group will meet at least 4-5 times.
